# %% [markdown]
# # Need to figure out zeros for: Soil, AEZ (it is less than -2.1E9) and slope (all of which are BIL files

# %%
import os
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
#import gdal
import geopandas as gpd
from shapely.geometry import Point, Polygon, mapping
import rasterio
import rasterio.plot
import rasterio.mask # an important package which allows you to only extract points within your shapefile
import rasterstats # gives us raster summaries within a shapefile
from rasterstats import zonal_stats # gives us raster summaries within a shapefile



#import osmnx as ox # open streetmap package
os.getcwd()
# Out:
# 'C:\\Users\\leogo\\OneDrive\\Desktop\\PhD\\Analysis\\scripts'

# %%
#os.chdir('../../')
#os.chdir('../')

os.getcwd()
# Out:
# 'C:\\Users\\leogo\\OneDrive\\Desktop\\PhD\\Analysis'

# %%
world_grid=gpd.read_file(os.path.join('data', 'shapefiles', 'world_grid_100.0km'))
geometry=world_grid.values #contains country name, metadata and

# %%
rasters_to_attach={"education":os.path.join("data", "raster","ClimAfr21_education_index","ClimAfr21_education index.tif"),
                  "technological_capital":os.path.join("data", "raster","ClimAfr08_technological_capital_index","ClimAfr08_technological capital index.tif"),
                  "infrastructure":os.path.join("data", "raster","ClimAfr23_infrastructure_index","ClimAfr23_infrastructure index.tif"),
                  "conflictuality":os.path.join("data", "raster","ClimAfr27_conflictuality_index","ClimAfr27_conflictuality index.tif"),
                  #"soil":os.path.join("data", "raster","HWSD_RASTER","hwsd.bil"),
                  "cattle_density":os.path.join("data", "raster","cattle_density_map","Cattle10km_AD_2010_v2_1.tif"),
                  #"AEZ":os.path.join("data", "raster","ClimAfr_AEZ","ClimAf_1_1981_2050_lpjm_mir5_B1_AEZAI_ann_avgCUR05_10km.tif"),
                  "financial_capital":os.path.join("data", "raster","ClimAfr09_financial_capital_index","ClimAfr09_financial capital index.tif"),
                  "rurality":os.path.join("data", "raster","ClimAfr13_rurality_index","ClimAfr13_rurality index.tif"),
                  "gender_gap":os.path.join("data", "raster","ClimAfr15_gender_gap_index","ClimAfr15_gender gap index.tif"),
                  "household_technological_capital":os.path.join("data", "raster","ClimAfr22_household_technology_index","ClimAfr22_household technology index.tif"),
                  "financial_development":os.path.join("data", "raster","ClimAfr24_financial_development_index","ClimAfr24_financial development index.tif"),
                  "richness":os.path.join("data", "raster","ClimAfr25_richness_index","ClimAfr25_richness index.tif"),
                  "governance":os.path.join("data", "raster","ClimAfr26_governance_index","ClimAfr26_governance index.tif"),
                  #"slope":os.path.join("data", "raster","global_slope_median","plate09.bil"),
                  "population_density":os.path.join("data", "raster","gridded_pop_world_population_density_2015","gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2015_2pt5_min.tif"),
                  "institutional_capital":os.path.join("data", "raster","ClimAfr10_institutional_capital_index","ClimAfr10_institutional capital index.tif"),
                  "AEZ":os.path.join("data", "raster","Harvest_Choice_AEZ","AEZ16 r2.0 - TIF", "AEZ16_CLAS--SSA.tif"),
                  "time_to_market_20_k":os.path.join("data", "raster","Harvest_Choice_Market_Travel","TravelTimeToMarket_SSA_GeoTiff","traveltimetomarket_ssa_020k.tif"),
                  "time_to_market_50_k":os.path.join("data", "raster","Harvest_Choice_Market_Travel","TravelTimeToMarket_SSA_GeoTiff","traveltimetomarket_ssa_050k.tif"),
                  "time_to_market_100_k":os.path.join("data", "raster","Harvest_Choice_Market_Travel","TravelTimeToMarket_SSA_GeoTiff","traveltimetomarket_ssa_100k.tif"),
                  "time_to_market_250_k":os.path.join("data", "raster","Harvest_Choice_Market_Travel","TravelTimeToMarket_SSA_GeoTiff","traveltimetomarket_ssa_250k.tif"),
                  "time_to_market_500_k":os.path.join("data", "raster","Harvest_Choice_Market_Travel","TravelTimeToMarket_SSA_GeoTiff","traveltimetomarket_ssa_500k.tif")}
                  #"pests_and_disease":os.path.join("data", "raster","Harvest_Choice_Pests_and_Disease","Pests_and_Disease.tiff")}
rasters_to_attach.keys()
#raster_labels,raster_keys=
raster_keys=[value for value, key in  rasters_to_attach.items()]
raster_labels=[key for value, key in  rasters_to_attach.items()]
print(raster_keys)
print('\n')
print(raster_labels)
# Out:
# ['education', 'technological_capital', 'infrastructure', 'conflictuality', 'cattle_density', 'financial_capital', 'rurality', 'gender_gap', 'household_technological_capital', 'financial_development', 'richness', 'governance', 'population_density', 'institutional_capital', 'AEZ', 'time_to_market_20_k', 'time_to_market_50_k', 'time_to_market_100_k', 'time_to_market_250_k', 'time_to_market_500_k']
#
#
# ['data\\raster\\ClimAfr21_education_index\\ClimAfr21_education index.tif', 'data\\raster\\ClimAfr08_technological_capital_index\\ClimAfr08_technological capital index.tif', 'data\\raster\\ClimAfr23_infrastructure_index\\ClimAfr23_infrastructure index.tif', 'data\\raster\\ClimAfr27_conflictuality_index\\ClimAfr27_conflictuality index.tif', 'data\\raster\\cattle_density_map\\Cattle10km_AD_2010_v2_1.tif', 'data\\raster\\ClimAfr09_financial_capital_index\\ClimAfr09_financial capital index.tif', 'data\\raster\\ClimAfr13_rurality_index\\ClimAfr13_rurality index.tif', 'data\\raster\\ClimAfr15_gender_gap_index\\ClimAfr15_gender gap index.tif', 'data\\raster\\ClimAfr22_household_technology_index\\ClimAfr22_household technology index.tif', 'data\\raster\\ClimAfr24_financial_development_index\\ClimAfr24_financial development index.tif', 'data\\raster\\ClimAfr25_richness_index\\ClimAfr25_richness index.tif', 'data\\raster\\ClimAfr26_governance_index\\ClimAfr26_governance index.tif', 'data\\raster\\gridded_pop_world_population_density_2015\\gpw_v4_population_density_adjusted_to_2015_unwpp_country_totals_rev11_2015_2pt5_min.tif', 'data\\raster\\ClimAfr10_institutional_capital_index\\ClimAfr10_institutional capital index.tif', 'data\\raster\\Harvest_Choice_AEZ\\AEZ16 r2.0 - TIF\\AEZ16_CLAS--SSA.tif', 'data\\raster\\Harvest_Choice_Market_Travel\\TravelTimeToMarket_SSA_GeoTiff\\traveltimetomarket_ssa_020k.tif', 'data\\raster\\Harvest_Choice_Market_Travel\\TravelTimeToMarket_SSA_GeoTiff\\traveltimetomarket_ssa_050k.tif', 'data\\raster\\Harvest_Choice_Market_Travel\\TravelTimeToMarket_SSA_GeoTiff\\traveltimetomarket_ssa_100k.tif', 'data\\raster\\Harvest_Choice_Market_Travel\\TravelTimeToMarket_SSA_GeoTiff\\traveltimetomarket_ssa_250k.tif', 'data\\raster\\Harvest_Choice_Market_Travel\\TravelTimeToMarket_SSA_GeoTiff\\traveltimetomarket_ssa_500k.tif']

# %%
AEZ_raster=os.path.join("data", "raster","Harvest_Choice_AEZ","AEZ16 r2.0 - TIF", "AEZ16_CLAS--SSA.tif")

mapping_categories={101:"Temperate / arid",
                    102:"Temperate / Semi-arid",
                    103:"Temperate / sub-humid",
                    104:"Temperate / humid",
                    211:"Subtropic - warm / arid",
                    212:"Subtropic - warm / semiarid",
                    213:"Subtropic - warm / subhumid",
                    214:"Subtropic - warm / humid",
                    221:"Subtropic - cool / arid",
                    222:"Subtropic - cool / semiarid",
                    223:"Subtropic - cool / subhumid",
                    224:"Subtropic - cool / humid",
                    311:"Tropic - warm / arid",
                    312:"Tropic - warm / semiarid",
                    313:"Tropic - warm / subhumid",
                    314:"Tropic - warm / humid",
                    321:"Tropic - cool / arid",
                    322:"Tropic - cool / semiarid",
                    323:"Tropic - cool / subhumid",
                    324:"Tropic - cool / humid",
                    400:"Boreal",
                   }

zonal_stats(world_grid, AEZ_raster,
            categorical=True, stats=["majority"])


#with rasterio.open(filepath) as src:
#        # can check the profile and type of src, but effectively is an open file command
#    affine = src.transform # transforms the raster dataset into the coordinate reference system
#    raster_array=rasterio.open(filepath).read(1) # why is this "1" here?
#    raster_array=raster_array.astype(float)
#    #raster_array[raster_array<-3.4e+38]=np.nan
#    raster_array[raster_array<-2e+9]=np.nan
#    raster_statistics_for_grid = pd.DataFrame(zonal_stats(shapefile,raster_array ,affine=affine,stats=[ 'mean', 'median', 'std', "majority"])) # calculates raster statistics within boundary of shapefile#

#    raster_statistics_for_grid=pd.concat([shapefile,raster_statistics_for_grid],axis=1)
#    grid_raster_merge=raster_statistics_for_grid



#    grid_raster_merge.columns=[column_name.replace("mean","mean_"+datatype) if column_name=="mean" else column_name  for column_name in grid_raster_merge.columns]
#    grid_raster_merge.columns=[column_name.replace("median","median_"+datatype) if column_name=="median" else column_name for column_name in grid_raster_merge.columns]
#    grid_raster_merge.columns=[column_name.replace("std","std_"+datatype) if column_name=="std" else column_name for column_name in grid_raster_merge.columns]
#    grid_raster_merge.columns=[column_name.replace("majority","majority_"+datatype) if column_name=="std" else column_name for column_name in grid_raster_merge.columns]
# Out:
# [{0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 116, 9: 5},
#  {0: 121},
#  {0: 65, 10: 56},
#  {0: 121},
#  {0: 27, 9: 8, 10: 86},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {9: 47, 10: 62, 13: 1},
#  {0: 110},
#  {9: 20, 10: 73, 13: 1, 14: 16},
#  {0: 121},
#  {9: 75, 10: 18, 13: 19, 14: 9},
#  {0: 121},
#  {9: 48, 13: 35, 14: 38},
#  {0: 121},
#  {9: 42, 10: 6, 12: 1, 13: 21, 14: 51},
#  {0: 121},
#  {9: 44, 13: 77},
#  {0: 121},
#  {9: 1, 10: 12, 13: 13, 14: 95},
#  {0: 121},
#  {10: 3, 13: 60, 14: 58},
#  {0: 121},
#  {10: 64, 14: 57},
#  {0: 121},
#  {10: 99, 14: 22},
#  {0: 110},
#  {10: 97, 14: 13},
#  {0: 110},
#  {9: 18, 10: 91, 14: 1},
#  {0: 121},
#  {10: 113, 14: 8},
#  {0: 121},
#  {9: 27, 10: 89, 13: 1, 14: 4},
#  {0: 121},
#  {10: 5, 14: 116},
#  {0: 121},
#  {9: 1, 10: 37, 13: 1, 14: 82},
#  {0: 121},
#  {9: 16, 13: 37, 14: 68},
#  {0: 121},
#  {13: 20, 14: 101},
#  {0: 110},
#  {9: 19, 13: 90, 14: 1},
#  {0: 110},
#  {13: 100, 14: 10},
#  {0: 121},
#  {8: 5, 9: 43, 13: 73},
#  {0: 121},
#  {9: 28, 11: 1, 12: 1, 13: 87, 14: 4},
#  {0: 121},
#  {8: 94, 9: 13, 13: 14},
#  {0: 121},
#  {8: 67, 9: 54},
#  {0: 121},
#  {8: 121},
#  {0: 121},
#  {7: 15, 8: 106},
#  {0: 121},
#  {7: 109, 8: 12},
#  {0: 121},
#  {7: 109, 8: 12},
#  {0: 110},
#  {7: 110},
#  {0: 110},
#  {7: 31, 8: 79},
#  {0: 121},
#  {7: 121},
#  {0: 121},
#  {0: 4, 7: 39, 8: 78},
#  {0: 121},
#  {0: 6, 7: 94, 8: 21},
#  {0: 121},
#  {0: 91, 7: 26, 8: 4},
#  {0: 121},
#  {0: 93, 7: 14, 8: 14},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 22},
#  {0: 22},
#  {0: 22},
#  {0: 22},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 110},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 117, 9: 4},
#  {0: 121},
#  {0: 74, 10: 47},
#  {0: 121},
#  {0: 13, 9: 82, 10: 26},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {9: 6, 10: 115},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {10: 110},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {10: 121},
#  {0: 110},
#  {9: 1, 10: 109},
#  {0: 110},
#  {10: 76, 14: 34},
#  {0: 121},
#  {9: 2, 10: 119},
#  {0: 121},
#  {9: 9, 13: 19, 14: 93},
#  {0: 121},
#  {10: 83, 14: 38},
#  {0: 121},
#  {13: 72, 14: 49},
#  {0: 121},
#  {10: 107, 14: 14},
#  {0: 121},
#  {10: 29, 13: 55, 14: 37},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {9: 2, 10: 102, 14: 17},
#  {0: 110},
#  {10: 110},
#  {0: 110},
#  {9: 71, 10: 39},
#  {0: 121},
#  {10: 121},
#  {0: 121},
#  {9: 96, 13: 25},
#  {0: 121},
#  {9: 15, 10: 22, 13: 24, 14: 60},
#  {0: 121},
#  {9: 8, 13: 86, 14: 27},
#  {0: 121},
#  {8: 21, 9: 34, 13: 38, 14: 28},
#  {0: 121},
#  {13: 111, 14: 10},
#  {0: 121},
#  {8: 49, 9: 21, 12: 2, 13: 49},
#  {0: 121},
#  {8: 24, 12: 16, 13: 81},
#  {0: 110},
#  {8: 48, 9: 26, 12: 2, 13: 34},
#  {0: 110},
#  {8: 10, 9: 13, 12: 18, 13: 69},
#  {0: 121},
#  {8: 121},
#  {0: 121},
#  {8: 99, 9: 16, 13: 6},
#  {0: 121},
#  {8: 121},
#  {0: 121},
#  {7: 1, 8: 120},
#  {0: 121},
#  {7: 110, 8: 11},
#  {0: 121},
#  {7: 7, 8: 114},
#  {0: 110},
#  {7: 110},
#  {0: 110},
#  {8: 110},
#  {0: 121},
#  {7: 121},
#  {0: 121},
#  {0: 67, 8: 54},
#  {0: 121},
#  {7: 113, 8: 8},
#  {0: 121},
#  {0: 121},
#  {0: 121},
#  {0: 5, 7: 28, 8: 88},
#  {0: 121},
#  {0: 121},
#  ...]

# %%
# Out:
# numpy.ndarray

# %%
#https://gis.stackexchange.com/questions/297076/how-to-calculate-mean-value-of-a-raster-for-each-polygon-in-a-shapefile
def merge_shape_file_with_raster(filepath,datatype, shapefile):
    with rasterio.open(filepath) as src:
        # can check the profile and type of src, but effectively is an open file command
        affine = src.transform # transforms the raster dataset into the coordinate reference system
        raster_array=rasterio.open(filepath).read(1) # why is this "1" here?
        raster_array=raster_array.astype(float)
        #raster_array[raster_array<-3.4e+38]=np.nan
        raster_array[raster_array<-2e+9]=np.nan
        raster_statistics_for_grid = pd.DataFrame(zonal_stats(shapefile,raster_array ,affine=affine,stats=[ 'mean', 'median', 'std', "majority"])) # calculates raster statistics within boundary of shapefile

    raster_statistics_for_grid=pd.concat([shapefile,raster_statistics_for_grid],axis=1)
    grid_raster_merge=raster_statistics_for_grid



    grid_raster_merge.columns=[column_name.replace("mean","mean_"+datatype) if column_name=="mean" else column_name  for column_name in grid_raster_merge.columns]
    grid_raster_merge.columns=[column_name.replace("median","median_"+datatype) if column_name=="median" else column_name for column_name in grid_raster_merge.columns]
    grid_raster_merge.columns=[column_name.replace("std","std_"+datatype) if column_name=="std" else column_name for column_name in grid_raster_merge.columns]
    grid_raster_merge.columns=[column_name.replace("majority","majority_"+datatype) if column_name=="std" else column_name for column_name in grid_raster_merge.columns]

    return grid_raster_merge;

# %%
world_grid_old=world_grid
for loop_index in range(len(rasters_to_attach)):
    print(raster_keys[loop_index])
    world_grid_new=merge_shape_file_with_raster(filepath=raster_labels[loop_index], datatype=raster_keys[loop_index], shapefile=world_grid_old)
    columns_to_add=["FID"]
    columns_to_add.extend(list(world_grid_new.columns.difference(world_grid_old.columns)))
    world_grid_old=pd.merge(world_grid_old,world_grid_new[world_grid_new.columns.intersection(columns_to_add)])
# Out:
# education
# technological_capital
# infrastructure
# conflictuality
# cattle_density
# financial_capital
# rurality
# gender_gap
# household_technological_capital
# financial_development
# richness
# governance
# population_density
# institutional_capital
# AEZ
# time_to_market_20_k
# time_to_market_50_k
# time_to_market_100_k
# time_to_market_250_k
# time_to_market_500_k

# %%
world_grid_old.to_csv(os.path.join("data","processed","hundred_km_grid_with_raster_info.csv"))

# %%
subsetting_non_na_values=world_grid_old.loc[:,"mean_"+raster_keys[0]].notna()
grid_raster_merge_non_na=world_grid_old.loc[subsetting_non_na_values,:]

# %%
grid_raster_merge_non_na.plot()

# %% [markdown]
# # Cells to test specific loop iterations #

# %%
loop_index=4

shapefile=world_grid
datatype=raster_keys[loop_index]
filepath=raster_labels[loop_index]
with rasterio.open(filepath) as src:
    # can check the profile and type of src, but effectively is an open file command
    affine = src.transform # transforms the raster dataset into the coordinate reference system
    raster_array=rasterio.open(filepath).read(1) # why is this "1" here?
    raster_array[raster_array<-3.4e+38]=np.nan
    raster_statistics_for_grid = pd.DataFrame(zonal_stats(shapefile,raster_array ,affine=affine,stats=[ 'mean', 'median', 'std'])) # calculates raster statistics within boundary of shapefile

    raster_statistics_for_grid=pd.concat([shapefile,raster_statistics_for_grid],axis=1)
    grid_raster_merge=raster_statistics_for_grid



    grid_raster_merge.columns=[column_name.replace("mean","mean_"+datatype) if column_name=="mean" else column_name  for column_name in grid_raster_merge.columns]
    grid_raster_merge.columns=[column_name.replace("median","median_"+datatype) if column_name=="median" else column_name for column_name in grid_raster_merge.columns]
    grid_raster_merge.columns=[column_name.replace("std","std_"+datatype) if column_name=="std" else column_name for column_name in grid_raster_merge.columns]
    
    
columns_to_add=["FID"]
columns_to_add.extend(list(world_grid_new.columns.difference(world_grid_old.columns)))
world_grid_old=pd.merge(world_grid_old,world_grid_new[world_grid_new.columns.intersection(columns_to_add)])
shapefile=world_grid_old
